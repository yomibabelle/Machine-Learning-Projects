# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GeeksforGeeks
# Out:
# /content/drive/MyDrive/GeeksforGeeks

# %%
# !git clone https://github.com/GeeksforgeeksDS/Machine-Learning---Priya-_-Customer-Segmentation.git
# Out:
# fatal: destination path 'Machine-Learning---Priya-_-Customer-Segmentation' already exists and is not an empty directory.
